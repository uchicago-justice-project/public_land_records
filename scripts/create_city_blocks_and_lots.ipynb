# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.ops import unary_union
from functools import cmp_to_key

from polygons import split_polygon, snake_sort, ns, sn, ew, we

# %%
quarters = gpd.read_file("../data/quarter_sections.geojson")
blocks1 = gpd.read_file("../data/blocks.json")
blocks2 = gpd.read_file("../data/39-14-27.json")
original_town = gpd.read_file("../data/original_town.json")

# %%
quarters.head()
# Out:
#    OBJECTID  TOWNSHIP  RANGE SECTN QUARTERSEC   IBL  FRACL  SHAPE_Length  \
# 0         1        37     14    13    N.E.1/4  NIBL      1   7131.482171
# 1         2        37     14    13    N.W.1/4  NIBL      1  10201.904596
# 2         3        37     14    14    N.E.1/4  NIBL      0  10670.819542
# 3         4        37     14    13    N.E.1/4  SIBL      1  10598.997285
# 4         5        37     14    13    N.W.1/4  SIBL      0  10794.114317
#
#      SHAPE_Area                                           geometry
# 0  2.781041e+06  POLYGON ((-87.57419 41.70273, -87.56941 41.702...
# 1  6.816353e+06  POLYGON ((-87.57982 41.70788, -87.58047 41.707...
# 2  7.116323e+06  POLYGON ((-87.59411 41.70029, -87.59398 41.700...
# 3  7.021105e+06  POLYGON ((-87.56442 41.70277, -87.56444 41.702...
# 4  6.416795e+06  POLYGON ((-87.57419 41.70273, -87.57476 41.702...

# %%
sect7 = unary_union(quarters.loc[(quarters['TOWNSHIP'] == 39)&(quarters['RANGE']==14)&(quarters['SECTN']=='7'), 'geometry'])

# %%
new_polygons = snake_sort(split_polygon(sect7, 8, 8).geoms, 8, "NE")

# %%
blocks3 = gpd.GeoDataFrame(data={'block': [i for i in range(1,65)]}, geometry=new_polygons)

# %%
blocks3.head()
# Out:
#    block                                           geometry
# 0      1  POLYGON ((-87.66937 41.89604, -87.66729 41.896...
# 1      2  POLYGON ((-87.67187 41.89600, -87.66973 41.896...
# 2      3  POLYGON ((-87.67436 41.89596, -87.67340 41.895...
# 3      4  POLYGON ((-87.67686 41.89592, -87.67584 41.895...
# 4      5  POLYGON ((-87.67936 41.89588, -87.67706 41.895...

# %%
blocks = gpd.GeoDataFrame(pd.concat([blocks1,blocks2,blocks3], ignore_index=True) )

# %%
blocks.rename(inplace=True, columns={'block': 'BLOCK', 'dim': 'DIM', 'logic': 'LOGIC'})
blocks.head()
# Out:
#    BLOCK  DIM       LOGIC                                           geometry
# 0     13  2,5  rows,snake  POLYGON ((-87.62584 41.87433, -87.62581 41.873...
# 1     12  2,5  rows,snake  POLYGON ((-87.62588 41.87562, -87.62585 41.874...
# 2      9  2,5  rows,snake  POLYGON ((-87.62588 41.87693, -87.62585 41.875...
# 3      8  2,5  rows,snake  POLYGON ((-87.62590 41.87818, -87.62588 41.877...
# 4      5  2,5  rows,snake  POLYGON ((-87.62588 41.87944, -87.62585 41.878...

# %%
blocks_with_quarters = gpd.sjoin(blocks, quarters, how="left", predicate='within')

# %%
ot = original_town.loc[0, 'geometry']

def in_original_town(geometry):
    return geometry.intersects(ot)

# %%
blocks_with_quarters['ORIGINALTOWN'] = blocks_with_quarters['geometry'].apply(in_original_town)

# %%
blocks_with_quarters[blocks_with_quarters['ORIGINALTOWN']]
# Out:
#      BLOCK   DIM       LOGIC  \
# 86      42   4,2  rows,snake
# 87      41   4,2  rows,snake
# 88      40   4,2  rows,snake
# 89      53   4,2  rows,snake
# 90      54   4,2  rows,snake
# ..     ...   ...         ...
# 500     59   2,3  rows,snake
# 501     61  2,4L  rows,snake
# 502     62  2,4L  rows,snake
# 503     64  2,4L  rows,snake
# 504     63  2,4L  rows,snake
#
#                                               geometry  index_right  OBJECTID  \
# 86   POLYGON ((-87.63556 41.88408, -87.63680 41.884...       3865.0    3866.0
# 87   POLYGON ((-87.63408 41.88409, -87.63532 41.884...       3865.0    3866.0
# 88   POLYGON ((-87.63250 41.88416, -87.63374 41.884...       3865.0    3866.0
# 89   POLYGON ((-87.63551 41.88294, -87.63675 41.882...          NaN       NaN
# 90   POLYGON ((-87.63395 41.88296, -87.63519 41.882...          NaN       NaN
# ..                                                 ...          ...       ...
# 500  POLYGON ((-87.64562 41.88868, -87.64558 41.887...       3866.0    3867.0
# 501  POLYGON ((-87.64733 41.88772, -87.64733 41.886...       3866.0    3867.0
# 502  POLYGON ((-87.64562 41.88771, -87.64558 41.886...       3866.0    3867.0
# 503  POLYGON ((-87.64732 41.88640, -87.64729 41.885...       3866.0    3867.0
# 504  POLYGON ((-87.64559 41.88641, -87.64559 41.885...       3866.0    3867.0
#
#      TOWNSHIP  RANGE SECTN QUARTERSEC  IBL  FRACL  SHAPE_Length    SHAPE_Area  \
# 86       39.0   14.0     9    S.E.1/4    0    0.0  10635.834476  7.069399e+06
# 87       39.0   14.0     9    S.E.1/4    0    0.0  10635.834476  7.069399e+06
# 88       39.0   14.0     9    S.E.1/4    0    0.0  10635.834476  7.069399e+06
# 89        NaN    NaN   NaN        NaN  NaN    NaN           NaN           NaN
# 90        NaN    NaN   NaN        NaN  NaN    NaN           NaN           NaN
# ..        ...    ...   ...        ...  ...    ...           ...           ...
# 500      39.0   14.0     9    S.W.1/4    0    0.0  10479.948969  6.864261e+06
# 501      39.0   14.0     9    S.W.1/4    0    0.0  10479.948969  6.864261e+06
# 502      39.0   14.0     9    S.W.1/4    0    0.0  10479.948969  6.864261e+06
# 503      39.0   14.0     9    S.W.1/4    0    0.0  10479.948969  6.864261e+06
# 504      39.0   14.0     9    S.W.1/4    0    0.0  10479.948969  6.864261e+06
#
#      ORIGINALTOWN
# 86           True
# 87           True
# 88           True
# 89           True
# 90           True
# ..            ...
# 500          True
# 501          True
# 502          True
# 503          True
# 504          True
#
# [67 rows x 15 columns]

# %%
len(blocks)
# Out:
# 707

# %%
len(blocks_with_quarters)
# Out:
# 707

# %%
for idx, row in blocks_with_quarters.loc[blocks_with_quarters['TOWNSHIP'].isnull()].iterrows():
    mask = quarters['geometry'].apply(lambda x : x.intersects(row['geometry']))
    candidates = quarters.loc[mask]
    
    winner = None
    most_overlap = 0
    
    for idx2, row2 in candidates.iterrows():
        overlap = row2['geometry'].intersection(row['geometry']).area
        if overlap > most_overlap:
            winner = idx2
            most_overlap = overlap
            
    if winner:
        blocks_with_quarters.loc[idx, ['OBJECTID','TOWNSHIP','RANGE','SECTN','QUARTERSEC','IBL','FRACL']] =\
        quarters.loc[winner, ['OBJECTID','TOWNSHIP','RANGE','SECTN','QUARTERSEC','IBL','FRACL']].values

# %%
len(blocks_with_quarters)
# Out:
# 707

# %%
blocks_with_quarters['TOWNSHIP'].isnull().sum()
# Out:
# 0

# %%
blocks_with_quarters.head()
# Out:
#    BLOCK  DIM       LOGIC                                           geometry  \
# 0     13  2,5  rows,snake  POLYGON ((-87.62584 41.87433, -87.62581 41.873...
# 1     12  2,5  rows,snake  POLYGON ((-87.62588 41.87562, -87.62585 41.874...
# 2      9  2,5  rows,snake  POLYGON ((-87.62588 41.87693, -87.62585 41.875...
# 3      8  2,5  rows,snake  POLYGON ((-87.62590 41.87818, -87.62588 41.877...
# 4      5  2,5  rows,snake  POLYGON ((-87.62588 41.87944, -87.62585 41.878...
#
#    index_right  OBJECTID  TOWNSHIP  RANGE SECTN QUARTERSEC IBL  FRACL  \
# 0       1519.0    1520.0      39.0   14.0    15    S.W.1/4   0    0.0
# 1          NaN    1488.0      39.0   14.0    15    N.W.1/4   0    0.0
# 2       1487.0    1488.0      39.0   14.0    15    N.W.1/4   0    0.0
# 3       1487.0    1488.0      39.0   14.0    15    N.W.1/4   0    0.0
# 4       1487.0    1488.0      39.0   14.0    15    N.W.1/4   0    0.0
#
#    SHAPE_Length    SHAPE_Area  ORIGINALTOWN
# 0  10738.940743  7.142300e+06         False
# 1           NaN           NaN         False
# 2  11216.048053  7.907387e+06         False
# 3  11216.048053  7.907387e+06         False
# 4  11216.048053  7.907387e+06         False

# %%
blocks = []
lots = []
townships = []
ranges = []
sections = []
quartersecs = []
original_towns = []
geometry = []

for idx, row in blocks_with_quarters.loc[(blocks_with_quarters['DIM'] != "")\
                                         &blocks_with_quarters['DIM'].notnull()].iterrows():
    try:
        x,y = map(int, row['DIM'].split(","))
    except:
        x,y = row['DIM'].split(",")
        y = int(y.replace("L", ''))
        x = int(x)
        print(idx)
    total = x * y
    
    logic = row['LOGIC'].split(",")
    
    if logic[0] == 'code':
        total = 9
        w,e = sorted(split_polygon(row['geometry'], 2, 1).geoms, key=cmp_to_key(we))
        e_list = sorted(split_polygon(e, 1, 8).geoms, key=cmp_to_key(ns))
        polygons = [w] + e_list
        
    else:
        starts = 'NE'
        if len(logic) == 3:
            starts = logic[2].upper()

        cols = logic[0] == 'cols' or logic[0] == 'col'
        
        snake_length = x
        if cols:
            snake_length = y
        
        polygons = snake_sort(split_polygon(row['geometry'],x, y).geoms, snake_length, starts, cols)
        
    blocks.extend([row['BLOCK'] for _ in range(total)])
    lots.extend([i for i in range(1, total+1)])
    townships.extend([row['TOWNSHIP'] for _ in range(total)])
    ranges.extend([row['RANGE'] for _ in range(total)])
    sections.extend([row['SECTN'] for _ in range(total)])
    quartersecs.extend([row['QUARTERSEC'] for _ in range(total)])
    original_towns.extend([row['ORIGINALTOWN'] for _ in range(total)])
    geometry.extend(polygons)
# Out:
# 52
# 501
# 502
# 503
# 504

# %%
city_lots = {
    'BLOCK': blocks,
    'LOT': lots,
    'TOWNSHIP': townships,
    'RANGE': ranges,
    'SECTN': sections,
    'QUARTERSEC': quartersecs,
    'ORIGINALTOWN': original_towns
}

# %%
city_lots_gdf = gpd.GeoDataFrame(city_lots, geometry=geometry)

# %%
city_lots_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bad7eb12bc08a12251c83831be4eb87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bad7eb12bc08a12251c83831be4eb87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4bad7eb12bc08a12251c83831be4eb87 = L.map(
#                 &quot;map_4bad7eb12bc08a12251c83831be4eb87&quot;,
#                 {
#                     center: [41.870936962938316, -87.63816568652655],
#                     crs: L.CRS.Simple,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4bad7eb12bc08a12251c83831be4eb87);
#
#
#
#
#
#             map_4bad7eb12bc08a12251c83831be4eb87.fitBounds(
#                 [[41.85283342568003, -87.65196468258472], [41.88904050019659, -87.62436669046836]],
#                 {}
#             );
#
#
#         function geo_json_49ab4f02a58fe924c4017df63bb26a8b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_49ab4f02a58fe924c4017df63bb26a8b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_49ab4f02a58fe924c4017df63bb26a8b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_49ab4f02a58fe924c4017df63bb26a8b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_49ab4f02a58fe924c4017df63bb26a8b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_49ab4f02a58fe924c4017df63bb26a8b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_49ab4f02a58fe924c4017df63bb26a8b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_49ab4f02a58fe924c4017df63bb26a8b = L.geoJson(null, {
#                 onEachFeature: geo_json_49ab4f02a58fe924c4017df63bb26a8b_onEachFeature,
#
#                 style: geo_json_49ab4f02a58fe924c4017df63bb26a8b_styler,
#                 pointToLayer: geo_json_49ab4f02a58fe924c4017df63bb26a8b_pointToLayer
#         });
#
#         function geo_json_49ab4f02a58fe924c4017df63bb26a8b_add (data) {
#             geo_json_49ab4f02a58fe924c4017df63bb26a8b
#                 .addData(data)
#                 .addTo(map_4bad7eb12bc08a12251c83831be4eb87);
#         }
#             geo_json_49ab4f02a58fe924c4017df63bb26a8b_add({&quot;bbox&quot;: [-87.65196468258472, 41.85283342568003, -87.62436669046836, 41.88904050019659], &quot;features&quot;: [{&quot;bbox&quot;: [-87.62517078706072, 41.87410489600274, -87.62450450882932, 41.87432857512328], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.62517078706072, 41.87432857512328], [-87.62450450882932, 41.87432381599306], [-87.62450450882932, 41.87410489600274], [-87.62517078706072, 41.87410489600274], [-87.62517078706072, 41.87432857512328]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;BLOCK&quot;: 13, &quot;LOT&quot;: 1, &quot;ORIGINALTOWN&quot;: false, &quot;QUARTERSEC&quot;: &quot;S.W.1/4&quot;, &quot;RANGE&quot;: 14.0, &quot;SECTN&quot;: &quot;15&quot;, &quot;TOWNSHIP&quot;: 39.0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-87.62583706529213, 41.87410489600274, -87.62517078706072, 41.87433333425351], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.62583125754, 41.87410489600274], [-87.62583706529213, 41.87433333425351], [-87.62517078706072, 41.87432857512328], [-87.62517078706072, 41.87410489600274], [-87.62583125754, 41.87410489600274]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;BLOCK&quot;: 13, &quot;LOT&quot;: 2, &quot;ORIGINALTOWN&quot;: false, &quot;QUARTERSEC&quot;: &quot;S.W.1/4&quot;, &quot;RANGE&quot;: 14.0, &quot;SECTN&quot;: &quot;15&quot;, &quot;TOWNSHIP&quot;: 39.0}, &quot;type&quo

# %%
blocks_with_quarters.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41610afd44cb3d699881ed965e21797b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41610afd44cb3d699881ed965e21797b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_41610afd44cb3d699881ed965e21797b = L.map(
#                 &quot;map_41610afd44cb3d699881ed965e21797b&quot;,
#                 {
#                     center: [41.881995876943954, -87.65206036613782],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_41610afd44cb3d699881ed965e21797b);
#
#
#
#
#
#             var tile_layer_458b966cd35af0ef5e4c63919faafa60 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_41610afd44cb3d699881ed965e21797b);
#
#
#             map_41610afd44cb3d699881ed965e21797b.fitBounds(
#                 [[41.83840915685523, -87.68684739752555], [41.92558259703268, -87.61727333475007]],
#                 {}
#             );
#
#
#         function geo_json_b84033f75f57ca16125f53c47a5406f0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b84033f75f57ca16125f53c47a5406f0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b84033f75f57ca16125f53c47a5406f0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b84033f75f57ca16125f53c47a5406f0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b84033f75f57ca16125f53c47a5406f0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b84033f75f57ca16125f53c47a5406f0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b84033f75f57ca16125f53c47a5406f0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b84033f75f57ca16125f53c47a5406f0 = L.geoJson(null, {
#                 onEachFeature: geo_json_b84033f75f57ca16125f53c47a5406f0_onEachFeature,
#
#                 style: geo_json_b84033f75f57ca16125f53c47a5406f0_styler,
#                 pointToLayer: geo_json_b84033f75f57ca16125f53c47a5406f0_pointToLayer
#         });
#
#         function geo_json_b84033f75f57ca16125f53c47a5406f0_add (data) {
#             geo_json_b84033f75f57ca16125f53c47a5406f0
#                 .addData(data)
#                 .addTo(map_41610afd44cb3d699881ed965e21797b);
#         }
#             geo_json_b84033f75f57ca16125f53c47a5406f0_add({&quot;bbox&quot;: [-87.68684739752555, 41.83840915685523, -87.61727333475007, 41.92558259703268], &quot;features&quot;: [{&quot;bbox&quot;: [-87.62583706529213, 41.873191142999666, -87.62450450882932, 41.87433333425351], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.62583706529213, 41.87433333425351], [-87.62580851051078, 41.87321017952056], [-87.62450450882932, 41.873191142999666], [-87.62450450882932, 41.87432381599306], [-87.62583706529213, 41.87433333425351]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;BLOCK&quot;: 13, &quot;DIM&quot;: &quot;2,5&quot;, &quot;FRACL&quot;: 0.0, &quot;IBL&quot;: &quot;0&quot;, &quot;LOGIC&quot;: &quot;rows,snake&quot;, &quot;OBJECTID&quot;: 1520.0, &quot;ORIGINALT

# %%
blocks_with_quarters.to_file("../data/city_blocks.geojson", driver="GeoJSON")
city_lots_gdf.to_file("../data/city_lots.geojson", driver="GeoJSON")
