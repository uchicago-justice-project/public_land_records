# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
gdf = gpd.read_file("../data/cook_county_with_geometries4.geojson")

# %%
# Out:
#    id     Cleaned Name        Purchaser Residence Social Status  \
# 0   0   ABBE CHRISTIAN   ABBE CHRISTIAN   UNKNOWN             A
# 1   1   ABBOTT ALLISON   ABBOTT ALLISON   UNKNOWN             A
# 2   2    ABBOTT JOSEPH    ABBOTT JOSEPH   UNKNOWN          None
# 3   3  ABBOTT SAMUEL S    ABBOTT SAMUEL   UNKNOWN          None
# 4   4  ABBOTT SAMUEL S  ABBOTT SAMUEL S   UNKNOWN          None
#
#   Aliquot Parts or Lot  Section Number Township Range  Meridian  ... Voided  \
# 0             LOT2NWNE            16.0      36N   13E       3.0  ...  False
# 1               LOT1SW             6.0      40N   13E       3.0  ...  False
# 2                 NWSW             3.0      37N   12E       3.0  ...  False
# 3                   SW            14.0      40N   13E       3.0  ...  False
# 4                   SE            15.0      40N   13E       3.0  ...  False
#
#    Lot Matches Name Matches Duplicate IBL  part block  lot    YEAR  \
# ...
